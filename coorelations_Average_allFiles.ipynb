# %%
import pandas as pd
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Ultimate_combined.csv")

# %%
stimulus_name =["A1_LP","A2_LP","A3_LP","A4_LP","A_HN","B_HN","C_LN","F_HN","G_HP","H_HP",
                "J_Ne","K_Ne","M_LN","N_LN","O_LN","P_HP","Q_HP","U_Ne","V_Ne","W_HN"]

# %%
data
# Out:
#        Participant Stimulus_Name   Valence   Arousal  ibi mean normalize  \
# 0    group33_v5_10         A1_LP  0.212979 -0.176462            0.075154
# 1    group33_v5_10         A2_LP  0.254343 -0.055548            0.068837
# 2    group33_v5_10         A3_LP  0.181181  0.225131            0.172213
# 3    group33_v5_10         A4_LP  0.257238 -0.061238            0.139323
# 4    group33_v5_10          A_HN -0.349531  0.100043            0.130201
# ..             ...           ...       ...       ...                 ...
# 815          ITA05          P_HP  0.375421  0.230108           -0.010442
# 816          ITA05          Q_HP  0.445799  0.227748           -0.030579
# 817          ITA05          U_Ne  0.237204 -0.165307            0.009838
# 818          ITA05          V_Ne  0.162086 -0.177226            0.058525
# 819          ITA05          W_HN -0.611566  0.063076           -0.038208
#
#      ibi min normalize  ibi max normalize  ibi skew normalize  \
# 0            -0.142492           0.333901            0.033165
# 1            -0.161548           0.286262            0.194387
# 2            -0.466440           0.448236           -1.371316
# 3            -0.161548           0.381541           -0.232387
# 4            -0.199659           0.448236           -0.030170
# ..                 ...                ...                 ...
# 815          -0.128878           0.179095            1.030293
# 816          -0.155275           0.126300            0.410025
# 817          -0.128878           0.240690            0.851887
# 818          -0.084881           0.205493            0.071978
# 819          -0.146476           0.108701            0.464682
#
#      ibi kurtosis normalize  ibi std normalize
# 0                 -0.462619           0.107462
# 1                 -0.791557           0.105185
# 2                  1.640165           0.213040
# 3                 -0.761423           0.124706
# 4                 -0.802215           0.154385
# ..                      ...                ...
# 815                1.132663           0.054638
# 816               -0.161517           0.060562
# 817                0.030250           0.080501
# 818               -0.738779           0.066594
# 819                0.107986           0.047342
#
# [820 rows x 10 columns]

# %%
filtered_data = data[data['Stimulus_Name'].isin(stimulus_name)]
average_data = filtered_data.groupby('Stimulus_Name').mean()
average_data
# Out:
# <ipython-input-5-ee8fdf0d5864>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   average_data = filtered_data.groupby('Stimulus_Name').mean()
#                 Valence   Arousal  ibi mean normalize  ibi min normalize  \
# Stimulus_Name
# A1_LP          0.215574 -0.199553           -0.043285          -0.213469
# A2_LP          0.257442 -0.062817           -0.024053          -0.183530
# A3_LP          0.183388  0.254590           -0.021443          -0.176689
# A4_LP          0.260372 -0.069251           -0.037947          -0.192087
# A_HN          -0.353790  0.113134           -0.015020          -0.177492
# B_HN          -0.403721  0.208809           -0.011199          -0.167216
# C_LN          -0.181161 -0.306041           -0.020502          -0.201978
# F_HN          -0.175160  0.344438           -0.035813          -0.188998
# G_HP           0.209222  0.328404           -0.024314          -0.171737
# H_HP           0.236766  0.368647           -0.032785          -0.207460
# J_Ne           0.082001 -0.299870           -0.029725          -0.176578
# K_Ne           0.058676 -0.343383           -0.073009          -0.212394
# M_LN          -0.241619 -0.190244           -0.032242          -0.229530
# N_LN          -0.279947 -0.131066            0.000582          -0.185025
# O_LN          -0.205377 -0.296811           -0.046354          -0.246983
# P_HP           0.207956  0.362502           -0.002066          -0.173523
# Q_HP           0.246940  0.358784           -0.052187          -0.177390
# U_Ne           0.131393 -0.260418           -0.057727          -0.197318
# V_Ne           0.089784 -0.279195           -0.047863          -0.188072
# W_HN          -0.338763  0.099368           -0.042083          -0.221124
#
#                ibi max normalize  ibi skew normalize  ibi kurtosis normalize  \
# Stimulus_Name
# A1_LP                   0.104614           -0.209719               -0.251774
# A2_LP                   0.152967           -0.111513                0.051978
# A3_LP                   0.121728           -0.110750               -0.250742
# A4_LP                   0.140313            0.100773               -0.167625
# A_HN                    0.153698           -0.015513               -0.217167
# B_HN                    0.162060            0.072788               -0.294519
# C_LN                    0.161785           -0.139179                0.502657
# F_HN                    0.117592           -0.078561               -0.136171
# G_HP                    0.142633            0.145469                0.189314
# H_HP                    0.154054           -0.158234                0.302623
# J_Ne                    0.144437            0.033007               -0.357176
# K_Ne                    0.065939           -0.043178               -0.323135
# M_LN                    0.156523           -0.237972                0.103071
# N_LN                    0.176933           -0.168049                0.583630
# O_LN                    0.166963           -0.075076                0.589745
# P_HP                    0.176778           -0.064902                0.227580
# Q_HP                    0.082955           -0.014555               -0.275554
# U_Ne                    0.098324            0.077900               -0.284460
# V_Ne                    0.112558            0.010886               -0.209275
# W_HN                    0.120363           -0.220640                0.667473
#
#                ibi std normalize
# Stimulus_Name
# A1_LP                   0.077766
# A2_LP                   0.080262
# A3_LP                   0.071611
# A4_LP                   0.078772
# A_HN                    0.081227
# B_HN                    0.085095
# C_LN                    0.080886
# F_HN                    0.075836
# G_HP                    0.073919
# H_HP                    0.083489
# J_Ne                    0.076255
# K_Ne                    0.070315
# M_LN                    0.091976
# N_LN                    0.079985
# O_LN                    0.095371
# P_HP                    0.079284
# Q_HP                    0.064483
# U_Ne                    0.075406
# V_Ne                    0.076511
# W_HN                    0.077872

# %% [markdown]
# # Arousal

# %%
features = average_data.iloc[:, 2:]
correlation_r2_values = []
for feature_name, feature_values in features.items():
  X = pd.to_numeric(average_data['Arousal'])
  y = pd.to_numeric(feature_values)
  correlation_coefficient = X.corr(y)
  r_squared = correlation_coefficient**2

  regression_coefficients = np.polyfit(X, y, 1)
  regression_line = np.poly1d(regression_coefficients)

  plt.scatter(X, y, label='Data Points')
  plt.plot(X, regression_line(X), color='red', label='Linear Regression Line')

  plt.xlabel('Ground_Truth_arousal')
  plt.ylabel(feature_name)
  plt.title(f'{feature_name} vs Ground_Truth_arousal ')
  plt.legend()
  correlation_text = f'Correlation: {correlation_coefficient:.4f}\nR-squared: {r_squared:.4f}'

  plt.text(0.95, 0.5, correlation_text, ha='left', va='center', color='black', fontsize=10, transform=plt.gcf().transFigure)
  correlation_r2_values.append({'Feature': f'{feature_name} vs Ground_Truth_Arousal', 'Correlation': correlation_coefficient, 'R-squared': r_squared})
  for i, txt in enumerate(X.index):
    plt.text(X[i], y[i], txt, ha='right', va='bottom', fontsize=8, color='black')
  plt.show()
