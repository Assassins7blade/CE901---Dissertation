# %%
import pandas as pd
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Ultimate_combined.csv")
# df = pd.read_csv("testing_merge_data.csv")
data = data.apply(lambda col: col.sort_values().reset_index(drop=True))

# %%
stimulus_name =["A1_LP","A2_LP","A3_LP","A4_LP","A_HN","B_HN","C_LN","F_HN","G_HP","H_HP",
                "J_Ne","K_Ne","M_LN","N_LN","O_LN","P_HP","Q_HP","U_Ne","V_Ne","W_HN"]

# %%
data
# Out:
#        Participant Stimulus_Name   Valence   Arousal  ibi mean normalize  \
# 0            GRP01         A1_LP -0.879700 -0.613159           -0.622233
# 1            GRP01         A1_LP -0.836817 -0.546479           -0.620995
# 2            GRP01         A1_LP -0.831306 -0.535460           -0.600623
# 3            GRP01         A1_LP -0.770899 -0.529998           -0.596952
# 4            GRP01         A1_LP -0.760351 -0.508861           -0.576349
# ..             ...           ...       ...       ...                 ...
# 815  group_33_v1_9          W_HN  0.536135  0.586412            0.441228
# 816  group_33_v1_9          W_HN  0.538077  0.615042            0.451058
# 817  group_33_v1_9          W_HN  0.539689  0.640659            0.490563
# 818  group_33_v1_9          W_HN  0.560961  0.647299            0.536451
# 819  group_33_v1_9          W_HN  0.567346  0.658271            0.860077
#
#      ibi min normalize  ibi max normalize  ibi skew normalize  \
# 0            -0.667431          -0.592629           -2.779368
# 1            -0.658442          -0.572757           -2.758367
# 2            -0.654341          -0.533014           -2.611546
# 3            -0.642308          -0.533014           -2.574309
# 4            -0.642308          -0.513142           -2.453715
# ..                 ...                ...                 ...
# 815           0.024961           0.987406            2.265989
# 816           0.026954           1.039707            2.294520
# 817           0.030579           1.103524            2.318665
# 818           0.098304           1.379658            2.356993
# 819           0.124454           1.724570            2.494507
#
#      ibi kurtosis normalize  ibi std normalize
# 0                 -1.745600           0.000000
# 1                 -1.677436           0.000000
# 2                 -1.673034           0.000000
# 3                 -1.668620           0.000000
# 4                 -1.633581           0.000000
# ..                      ...                ...
# 815                7.389804           0.318587
# 816                8.403131           0.346850
# 817                8.863024           0.378925
# 818                9.129916           0.413833
# 819               10.253660           0.609280
#
# [820 rows x 10 columns]

# %%
filtered_data = data[data['Stimulus_Name'].isin(stimulus_name)]
average_data = filtered_data.groupby('Stimulus_Name').mean()
average_data
# Out:
# <ipython-input-5-ee8fdf0d5864>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   average_data = filtered_data.groupby('Stimulus_Name').mean()
#                 Valence   Arousal  ibi mean normalize  ibi min normalize  \
# Stimulus_Name
# A1_LP         -0.630731 -0.447063           -0.507401          -0.627295
# A2_LP         -0.424284 -0.362233           -0.212215          -0.525188
# A3_LP         -0.338011 -0.319033           -0.114905          -0.330641
# A4_LP         -0.274860 -0.281914           -0.092325          -0.262997
# A_HN          -0.218113 -0.249161           -0.073174          -0.241591
# B_HN          -0.167121 -0.219553           -0.059370          -0.225060
# C_LN          -0.101756 -0.188618           -0.048277          -0.207952
# F_HN          -0.024662 -0.153052           -0.037392          -0.194116
# G_HP           0.007929 -0.107583           -0.029401          -0.180582
# H_HP           0.034529 -0.072625           -0.020614          -0.166835
# J_Ne           0.060239 -0.037814           -0.011104          -0.153478
# K_Ne           0.085082  0.063634           -0.003605          -0.142849
# M_LN           0.114694  0.118451            0.007566          -0.134343
# N_LN           0.145877  0.167036            0.017960          -0.124046
# O_LN           0.174032  0.226480            0.029576          -0.109953
# P_HP           0.202343  0.269004            0.044637          -0.093232
# Q_HP           0.239377  0.310998            0.060577          -0.077672
# U_Ne           0.286208  0.360234            0.076633          -0.058801
# V_Ne           0.360006  0.412702            0.098604          -0.035067
# W_HN           0.469198  0.510137            0.225193           0.003105
#
#                ibi max normalize  ibi skew normalize  ibi kurtosis normalize  \
# Stimulus_Name
# A1_LP                  -0.370486           -1.875000               -1.468909
# A2_LP                  -0.042103           -1.136028               -1.184921
# A3_LP                  -0.006714           -0.871176               -1.035630
# A4_LP                   0.015483           -0.672506               -0.934417
# A_HN                    0.032264           -0.532097               -0.835347
# B_HN                    0.053298           -0.426739               -0.748172
# C_LN                    0.069561           -0.311736               -0.655664
# F_HN                    0.080643           -0.218917               -0.580948
# G_HP                    0.097060           -0.133953               -0.478085
# H_HP                    0.114290           -0.065233               -0.376672
# J_Ne                    0.131204           -0.001877               -0.284461
# K_Ne                    0.148561            0.057548               -0.184831
# M_LN                    0.165369            0.143127               -0.058866
# N_LN                    0.184066            0.251188                0.056369
# O_LN                    0.208602            0.341998                0.211083
# P_HP                    0.238749            0.427280                0.429469
# Q_HP                    0.264590            0.554593                0.725130
# U_Ne                    0.299892            0.736199                1.211755
# V_Ne                    0.374896            0.982917                1.865177
# W_HN                    0.653994            1.543393                4.778414
#
#                ibi std normalize
# Stimulus_Name
# A1_LP                   0.014546
# A2_LP                   0.028214
# A3_LP                   0.032672
# A4_LP                   0.036354
# A_HN                    0.039751
# B_HN                    0.043257
# C_LN                    0.046984
# F_HN                    0.051285
# G_HP                    0.056462
# H_HP                    0.062079
# J_Ne                    0.067887
# K_Ne                    0.072664
# M_LN                    0.079032
# N_LN                    0.087015
# O_LN                    0.095570
# P_HP                    0.104974
# Q_HP                    0.115483
# U_Ne                    0.130034
# V_Ne                    0.163433
# W_HN                    0.248625

# %% [markdown]
# # Arousal

# %%
features = average_data.iloc[:, 2:]
correlation_r2_values = []
for feature_name, feature_values in features.items():
  X = pd.to_numeric(average_data['Arousal'])
  y = pd.to_numeric(feature_values)
  correlation_coefficient = X.corr(y)
  r_squared = correlation_coefficient**2

  regression_coefficients = np.polyfit(X, y, 1)
  regression_line = np.poly1d(regression_coefficients)

  plt.scatter(X, y, label='Data Points')
  plt.plot(X, regression_line(X), color='red', label='Linear Regression Line')

  plt.xlabel('Ground_Truth_arousal')
  plt.ylabel(feature_name)
  plt.title(f'{feature_name} vs Ground_Truth_arousal ')
  plt.legend()
  correlation_text = f'Correlation: {correlation_coefficient:.4f}\nR-squared: {r_squared:.4f}'

  plt.text(0.95, 0.5, correlation_text, ha='left', va='center', color='black', fontsize=10, transform=plt.gcf().transFigure)
  correlation_r2_values.append({'Feature': f'{feature_name} vs Ground_Truth_Arousal', 'Correlation': correlation_coefficient, 'R-squared': r_squared})
  for i, txt in enumerate(X.index):
    plt.text(X[i], y[i], txt, ha='right', va='bottom', fontsize=8, color='black')
  plt.show()

# %%
# result_df = pd.DataFrame(correlation_r2_values)
# result_df.to_csv('mean_correlation_r2_values_arousal.csv', index=False)
